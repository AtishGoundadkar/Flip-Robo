# %% [markdown]
# ## CUSTOMER RETENTION DATASET

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stat
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None) # to see all the rows

# %% [markdown]
# ### Import and Explore Dataset

# %%
customer=pd.read_csv("customer_retention_dataset.csv",sep='	')
customer
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# 5                  Female         31-40 years
# 6                    Male         41-50 yaers
# 7                    Male         41-50 yaers
# 8                  Female  Less than 20 years
# 9                  Female         31-40 years
# 10                   Male         31-40 years
# 11                 Female         41-50 yaers
# 12                 Female  51 years and above
# 13                 Female         31-40 years
# 14                 Female         21-30 years
# 15                 Female         21-30 years
# 16                   Male         31-40 years
# 17                   Male         41-50 yaers
# 18                 Female         41-50 yaers
# ...

# %%
customer.shape
# Out:
# (269, 71)

# %%
customer.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
customer.isnull().sum()
# Out:
# 1Gender of respondent                                                                                                                                                                                                  0
# 2 How old are you?                                                                                                                                                                                                     0
# 3 Which city do you shop online from?                                                                                                                                                                                  0
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  0
# ...

# %% [markdown]
# from above we can conclude there are no null values in this dataset.

# %%
customer.dtypes
# Out:
# 1Gender of respondent                                                                                                                                                                                                  object
# 2 How old are you?                                                                                                                                                                                                     object
# 3 Which city do you shop online from?                                                                                                                                                                                  object
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                   int64
# ...

# %% [markdown]
# We can conclude all columns are of object type

# %% [markdown]
# ## Exploratory Data Analysis

# %%
customer.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
#plt.figure(figsize=(10,10))
sns.countplot(customer['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# Female customers are higher in number compared to male customer.

# %%
sns.countplot?

# %%
plt.figure(figsize=(10,10))
sns.countplot(customer['2 How old are you? '],hue='1Gender of respondent',data=customer)
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(customer['3 Which city do you shop online from?'],hue='1Gender of respondent',data=customer)
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=customer['4 What is the Pin Code of where you shop online from?'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='4 What is the Pin Code of where you shop online from?'>

# %%
plt.figure(figsize=(7,7))
plt.title
sns.countplot(customer['5 Since How Long You are Shopping Online ?'],hue='1Gender of respondent',data=customer)
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot(customer['6 How many times you have made an online purchase in the past 1 year?'])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.countplot(customer['7 How do you access the internet while shopping on-line?'],hue='1Gender of respondent',data=customer)
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.countplot(customer['8 Which device do you use to access the online shopping?'],hue='1Gender of respondent',data=customer)
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.countplot(customer['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '])
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(customer['10 What is the operating system (OS) of your device?\t\t\t\t                                          '],hue='2 How old are you? ',data=customer,)
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
plt.title('Which device do you use to access the online shopping?')
sns.countplot(customer['8 Which device do you use to access the online shopping?'],hue='2 How old are you? ',data=customer)
# Out:
# <AxesSubplot:title={'center':'Which device do you use to access the online shopping?'}, xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
cust=['1Gender of respondent', '2 How old are you? ',
       '3 Which city do you shop online from?',
       '4 What is the Pin Code of where you shop online from?',
       '5 Since How Long You are Shopping Online ?',
       '6 How many times you have made an online purchase in the past 1 year?',
       '7 How do you access the internet while shopping on-line?',
       '8 Which device do you use to access the online shopping?',
       '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
       '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
       '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
       '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
       '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
       '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
       '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',
       '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',
       '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ',
       '18 The content on the website must be easy to read and understand',
       '19 Information on similar product to the one highlighted  is important for product comparison',
       '20 Complete information on listed seller and product being offered is important for purchase decision.',
       '21 All relevant information on listed products must be stated clearly',
       '22 Ease of navigation in website', '23 Loading and processing speed',
       '24 User friendly Interface of the website',
       '25 Convenient Payment methods',
       '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
       '27 Empathy (readiness to assist with queries) towards the customers',
       '28 Being able to guarantee the privacy of the customer',
       '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
       '30 Online shopping gives monetary benefit and discounts',
       '31 Enjoyment is derived from shopping online',
       '32 Shopping online is convenient and flexible',
       '33 Return and replacement policy of the e-tailer is important for purchase decision',
       '34 Gaining access to loyalty programs is a benefit of shopping online',
       '35 Displaying quality Information on the website improves satisfaction of customers',
       '36 User derive satisfaction while shopping on a good quality website or application',
       '37 Net Benefit derived from shopping online can lead to users satisfaction',
       '38 User satisfaction cannot exist without trust',
       '39 Offering a wide variety of listed product in several category',
       '40 Provision of complete and relevant product information',
       '41 Monetary savings',
       '42 The Convenience of patronizing the online retailer',
       '43 Shopping on the website gives you the sense of adventure',
       '44 Shopping on your preferred e-tailer enhances your social status',
       '45 You feel gratification shopping on your favorite e-tailer',
       '46 Shopping on the website helps you fulfill certain roles',
       '47 Getting value for money spent',
       'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
       'Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options', 'Speedy order delivery ',
       'Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before',
       'Which of the Indian online retailer would you recommend to a friend?']
cust
# Out:
# ['1Gender of respondent',
#  '2 How old are you? ',
#  '3 Which city do you shop online from?',
#  '4 What is the Pin Code of where you shop online from?',
#  '5 Since How Long You are Shopping Online ?',
#  '6 How many times you have made an online purchase in the past 1 year?',
#  '7 How do you access the internet while shopping on-line?',
#  '8 Which device do you use to access the online shopping?',
#  '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#  '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#  '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#  '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
plt.figure(figsize=(5,5))
plt.title('What browser do you run on your device to access the website?')
sns.countplot(customer['11 What browser do you run on your device to access the website?\t\t\t                                                          '])
# Out:
# <AxesSubplot:title={'center':'What browser do you run on your device to access the website?'}, xlabel='11 What browser do you run on your device to access the website?\t\t\t                                                          ', ylabel='count'>

# %%
sns.countplot?

# %%
plt.figure(figsize=(8,5))
plt.title('Which channel did you follow to arrive at your favorite online store for the first time?')
sns.countplot(customer['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '])
# Out:
# <AxesSubplot:title={'center':'Which channel did you follow to arrive at your favorite online store for the first time?'}, xlabel='12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(8,8))
plt.title('After first visit, how do you reach the online retail store?')
sns.countplot(customer['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '])
# Out:
# <AxesSubplot:title={'center':'After first visit, how do you reach the online retail store?'}, xlabel='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(8,8))
plt.title('How much time do you explore the e- retail store before making a purchase decision?')
sns.countplot(customer['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '],hue='1Gender of respondent',data=customer)
# Out:
# <AxesSubplot:title={'center':'How much time do you explore the e- retail store before making a purchase decision?'}, xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(8,8))
plt.title('What is your preferred payment Option?')
sns.countplot(customer['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '],hue='2 How old are you? ',data=customer)
# Out:
# <AxesSubplot:title={'center':'What is your preferred payment Option?'}, xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>

# %%
plt.figure(figsize=(8,8))
plt.title('How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?')
sns.countplot(customer['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '],hue='1Gender of respondent',data=customer)
plt.xticks(rotation=25, horizontalalignment='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Sometimes'),
#   Text(1, 0, 'Very frequently'),
#   Text(2, 0, 'Never'),
#   Text(3, 0, 'Frequently')])

# %%
plt.figure(figsize=(8,8))
plt.title('Why did you abandon the “Bag”, “Shopping Cart”?')
sns.countplot(customer['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '])
plt.xticks(rotation=65, horizontalalignment='right')
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Lack of trust'),
#   Text(1, 0, 'Promo code not applicable'),
#   Text(2, 0, 'Better alternative offer'),
#   Text(3, 0, 'Change in price'),
#   Text(4, 0, 'No preferred mode of payment')])

# %%
sns.countplot?

# %%
plt.figure(figsize=(8,8))
plt.title('The content on the website must be easy to read and understand')
sns.countplot(customer['18 The content on the website must be easy to read and understand'])
plt.xticks(rotation=65, horizontalalignment='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Agree (4)'),
#   Text(1, 0, 'Strongly agree (5)'),
#   Text(2, 0, 'Strongly disagree (1)'),
#   Text(3, 0, 'Indifferent (3)')])

# %%
CC=['18 The content on the website must be easy to read and understand',
 '19 Information on similar product to the one highlighted  is important for product comparison',
 '20 Complete information on listed seller and product being offered is important for purchase decision.',
 '21 All relevant information on listed products must be stated clearly',
 '22 Ease of navigation in website',
 '23 Loading and processing speed',
 '24 User friendly Interface of the website',
 '25 Convenient Payment methods',
 '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
 '27 Empathy (readiness to assist with queries) towards the customers',
 '28 Being able to guarantee the privacy of the customer',
 '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
 '30 Online shopping gives monetary benefit and discounts',
 '31 Enjoyment is derived from shopping online',
 '32 Shopping online is convenient and flexible',
 '33 Return and replacement policy of the e-tailer is important for purchase decision',
 '34 Gaining access to loyalty programs is a benefit of shopping online',
 '35 Displaying quality Information on the website improves satisfaction of customers',
 '36 User derive satisfaction while shopping on a good quality website or application',
 '37 Net Benefit derived from shopping online can lead to users satisfaction',
 '38 User satisfaction cannot exist without trust',
 '39 Offering a wide variety of listed product in several category', ]

CC
# Out:
# ['18 The content on the website must be easy to read and understand',
#  '19 Information on similar product to the one highlighted  is important for product comparison',
#  '20 Complete information on listed seller and product being offered is important for purchase decision.',
#  '21 All relevant information on listed products must be stated clearly',
#  '22 Ease of navigation in website',
#  '23 Loading and processing speed',
#  '24 User friendly Interface of the website',
#  '25 Convenient Payment methods',
#  '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
#  '27 Empathy (readiness to assist with queries) towards the customers',
#  '28 Being able to guarantee the privacy of the customer',
#  '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
#  '30 Online shopping gives monetary benefit and discounts',
#  '31 Enjoyment is derived from shopping online',
# ...

# %%
ncols,nrows=(12,2)

# %%
plt.figure(figsize=(16,150))
for index,col in enumerate(CC):
    plt.subplot(ncols,nrows,index+1)
    sns.countplot(customer[CC[index]],hue='1Gender of respondent',data=customer)
    plt.xticks(rotation=25, horizontalalignment='right')

# %%
sns.countplot?

# %%
CC2=['40 Provision of complete and relevant product information',
       '41 Monetary savings',
       '42 The Convenience of patronizing the online retailer',
       '43 Shopping on the website gives you the sense of adventure',
       '44 Shopping on your preferred e-tailer enhances your social status',
       '45 You feel gratification shopping on your favorite e-tailer',
       '46 Shopping on the website helps you fulfill certain roles',
       '47 Getting value for money spent',
       
       ]

CC2
# Out:
# ['40 Provision of complete and relevant product information',
#  '41 Monetary savings',
#  '42 The Convenience of patronizing the online retailer',
#  '43 Shopping on the website gives you the sense of adventure',
#  '44 Shopping on your preferred e-tailer enhances your social status',
#  '45 You feel gratification shopping on your favorite e-tailer',
#  '46 Shopping on the website helps you fulfill certain roles',
#  '47 Getting value for money spent']

# %%
ncols,nrows=(16,2)

# %%
plt.figure(figsize=(16,150))
for index,col in enumerate(CC2):
    plt.subplot(ncols,nrows,index+1)
    sns.countplot(customer[CC2[index]])
    plt.xticks(rotation=25, horizontalalignment='right')

# %%
CC5=['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
       'Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',]

CC5
# Out:
# ['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
#  'Easy to use website or application',
#  'Visual appealing web-page layout',
#  'Wild variety of product on offer',
#  'Complete, relevant description information of products',
#  'Fast loading website speed of website and application',
#  'Reliability of the website or application',
#  'Quickness to complete purchase']

# %%
ncols,nrows=(16,2)

# %%
plt.figure(figsize=(16,300))
for index,col in enumerate(CC5):
    plt.subplot(ncols,nrows,index+1)
    sns.countplot(customer[CC5[index]])
    plt.xticks(rotation=25, horizontalalignment='right')

# %%
CC3=['Availability of several payment options', 'Speedy order delivery ',
       'Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       ]

CC3
# Out:
# ['Availability of several payment options',
#  'Speedy order delivery ',
#  'Privacy of customers’ information',
#  'Security of customer financial information',
#  'Perceived Trustworthiness',
#  'Presence of online assistance through multi-channel',
#  'Longer time to get logged in (promotion, sales period)',
#  'Longer time in displaying graphics and photos (promotion, sales period)']

# %%
ncols,nrows=(16,2)

# %%
plt.figure(figsize=(16,300))
for index,col in enumerate(CC3):
    plt.subplot(ncols,nrows,index+1)
    sns.countplot(customer[CC3[index]])
    plt.xticks(rotation=25, horizontalalignment='right')

# %%
CC4=['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
       'Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',]
CC4
# Out:
# ['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
#  'Easy to use website or application',
#  'Visual appealing web-page layout',
#  'Wild variety of product on offer']

# %%
ncols,nrows=(16,1)

# %%
plt.figure(figsize=(16,400))
for index,col in enumerate(CC4):
    plt.subplot(ncols,nrows,index+1)
    sns.countplot(customer[CC4[index]],hue='2 How old are you? ',data=customer)
    plt.xticks(rotation=25, horizontalalignment='right')
